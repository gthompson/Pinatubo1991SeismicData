# %% [markdown]
# # QuakeML to REA
# The goal of this notebook is to merge events from the QuakeML file into the REA database we created from the MiniSEED files in WAV.

# %%
import os
import glob
import pickle
from obspy import UTCDateTime, read, read_events
from obspy.core.event import Comment #Event, Origin, Arrival, Pick, WaveformStreamID, Catalog

SOURCE_DIR = '/data/Pinatubo/PHASE'
REPO_DIR = '/home/thompsong/Developer/Pinatubo1991SeismicData'
REA_DIR = '/data/SEISAN_DB/REA/PINAT2'
WAV_DIR = '/data/SEISAN_DB/WAV/PINAT'
catalogqml = os.path.join(REPO_DIR, 'metadata', 'pinatubo_catalog.xml') 
wavqmlfile = os.path.join(REPO_DIR, 'metadata', 'pinatubo_wavcatalog.xml') 
catalogpkl = catalogqml.replace('.xml', '.pkl')
if os.path.isfile(catalogpkl):
    with open(catalogpkl, "rb") as f:
        catalog = pickle.load(f)
else:
    catalog = read_events(catalogqml)
    with open(catalogpkl, "wb") as f:
        pickle.dump(catalog, f)

# %% [markdown]
# We need to try to associate each event in the catalog (which comes from picks, not waveforms), with a corresponding S-file.
#
# Let's associate each ObsPy Event object in the ObsPy Catalog object with the best matching Seisan WAV file.

# %%
import pandas as pd
def make_miniseed_dataframe(wav_directory):
    """
    Associates MiniSEED files from a Seisan WAV database with Pick objects in an ObsPy Catalog.
    If a Pick's time falls within a MiniSEED file's time range, a Comment is added to the Event.

    Parameters:
        catalog (obspy.core.event.Catalog): The ObsPy Catalog containing Events with Picks.
        wav_directory (str): Path to the Seisan WAV database (e.g., "WAV/").

    Returns:
        obspy.core.event.Catalog: The updated Catalog with associated MiniSEED file paths in Comments.
    """

    # 🔹 Step 1: Load MiniSEED files and extract time windows
    #miniseed_files = sorted(glob.glob(os.path.join(f"{wav_directory}/1991/??/1991*"), recursive=True))  # Adjust pattern if needed
    pattern = f"{wav_directory}/1991/[0-1][0-9]/1991*"
    miniseed_files = sorted(glob.glob(pattern))
    miniseed_time_ranges = []

    for file in miniseed_files:
        print(file)
        try:
            stream = read(file)
            start_time = min(tr.stats.starttime for tr in stream)
            end_time = max(tr.stats.endtime for tr in stream)
            miniseed_time_ranges.append((file, start_time, end_time))
        except Exception as e:
            print(f"❌ Error reading {file}: {e}")
    
    print(f"✅ Loaded {len(miniseed_time_ranges)} MiniSEED files for association.")
    # Create a pandas DataFrame
    df = pd.DataFrame(miniseed_time_ranges, columns=['file', 'start_time', 'end_time'])
    return df

print('catalog=',catalog)
csv_filename = os.path.join(REPO_DIR, 'metadata', "miniseed_time_ranges.csv")
if os.path.isfile(csv_filename):
    df = pd.read_csv(csv_filename, index_col=None)
    
    # Convert DataFrame columns to ObsPy UTCDateTime objects
    df["start_time"] = df["start_time"].apply(UTCDateTime)
    df["end_time"] = df["end_time"].apply(UTCDateTime)    
else:
    df = make_miniseed_dataframe(WAV_DIR)
    if len(df)>0:
        df.to_csv(csv_filename, index=False)
display(df)
# Out:
# catalog= 11135 Event(s) in Catalog:
# 1970-03-02T13:05:08.030000Z | None, None
# 1970-03-02T13:05:08.030000Z | None, None
# ...
# 1991-08-21T15:51:45.640000Z | None, None
# 1991-08-21T15:51:45.640000Z | None, None
# To see all events call 'print(CatalogObject.__str__(print_all=True))'
#                                                     file  \
# 0      /data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-0...
# 1      /data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-0...
# 2      /data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1...
# 3      /data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1...
# 4      /data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1...
# ...                                                  ...
# 21446  /data/SEISAN_DB/WAV/PINAT/1991/12/1991-12-05-2...
# 21447  /data/SEISAN_DB/WAV/PINAT/1991/12/1991-12-05-2...
# 21448  /data/SEISAN_DB/WAV/PINAT/1991/12/1991-12-05-2...
# 21449  /data/SEISAN_DB/WAV/PINAT/1991/12/1991-12-05-2...
# 21450  /data/SEISAN_DB/WAV/PINAT/1991/12/1991-12-06-0...
#
#                         start_time                     end_time
# 0      1991-05-01T03:10:09.950000Z  1991-05-01T03:10:50.572400Z
# 1      1991-05-01T03:39:42.521000Z  1991-05-01T03:40:58.696680Z
# 2      1991-05-01T10:45:26.647000Z  1991-05-01T10:46:12.348440Z
# 3      1991-05-01T10:49:40.597000Z  1991-05-01T10:50:26.298440Z
# 4      1991-05-01T11:20:14.116000Z  1991-05-01T11:20:59.817440Z
# ...                            ...                          ...
# 21446  1991-12-05T21:12:24.596000Z  1991-12-05T21:13:40.771680Z
# 21447  1991-12-05T21:19:46.469000Z  1991-12-05T21:21:02.644680Z
# 21448  1991-12-05T21:22:03.602000Z  1991-12-05T21:23:19.777680Z
# 21449  1991-12-05T23:13:17.408000Z  1991-12-05T23:14:33.583680Z
# 21450  1991-12-06T04:37:31.783000Z  1991-12-06T04:38:47.958680Z
#
# [21451 rows x 3 columns]

# %% [markdown]
# Now we need to loop through each Event and try to match this origin time against the wfdisc dataframe, and look for the corresponding S-file name. Then replace that S-file with a new one we write with _write_nordic. or write a new event, if no match found.

# %%
import pandas as pd
import shutil
from obspy.io.nordic.core import blanksfile, _write_nordic
def associate_miniseed_with_events(catalog, df):
    """
    Associates MiniSEED files from a Seisan WAV database with Pick objects in an ObsPy Catalog.
    If a Pick's time falls within a MiniSEED file's time range, a Comment is added to the Event.

    Parameters:
        catalog (obspy.core.event.Catalog): The ObsPy Catalog containing Events with Picks.
        wav_directory (str): Path to the Seisan WAV database (e.g., "WAV/").

    Returns:
        obspy.core.event.Catalog: The updated Catalog with associated MiniSEED file paths in Comments.
    """

    # Iterate through Events & Picks to check time association
    total_matched = 0
    total_unmatched = 0

    for event in catalog:
        associated_files = set()  # Track unique MiniSEED files per event
        
        for pick in event.picks:
            pick_time = pick.time  # Extract pick time

            # Filter DataFrame to find matching file_path
            matching_rows = df[(df["start_time"] <= pick_time) & (df["end_time"] >= pick_time)]
            
            # Add matching file paths to the set
            matching_files = matching_rows["file"].tolist()
            if matching_files:
                associated_files.update(matching_files)

        # Print or use associated_files as needed
        print(f"Event: {event.resource_id}, Associated Files: {associated_files}") 

        # Add MiniSEED file paths as Comments in Event
        if associated_files:
            associated_files = sorted(list(associated_files))
            basenames = [os.path.basename(f) for f in associated_files]
            comment_text = "Associated MiniSEED files:\n" + "\n".join(basenames)
            event.comments.append(Comment(text=comment_text))
            print(f"📌 Added MiniSEED association for Event at {event.origins[0].time}")

        otime = event.origins[0].time
        ymdir = os.path.join(REA_DIR, otime.strftime('%Y'), otime.strftime('%m'))
        os.makedirs(ymdir, exist_ok=True)    

        num_wavfiles = len(associated_files)
        if num_wavfiles>0:
            # rewrite the S-file, with the picks too
            wavfile = associated_files[-1]
            st = read(wavfile, format='MSEED')
            stime = st[0].stats.starttime
            filename = stime.strftime("%d-%H%M-%S") + "L.S" + stime.strftime("%Y%m") 
            print(f'Found {num_wavfiles} matching WAVs. creating {filename} in {ymdir}')
            _write_nordic(event, filename, userid='gt  ', evtype='L', outdir=ymdir, wavefiles=os.path.basename(wavfile), 
                      explosion=False, nordic_format='OLD', overwrite=True, high_accuracy=False)  
            total_matched += 1
        else:
            # write a new sfile with the picks
            ymdir2 = ymdir.replace('PINAT', 'PINATnew')
            os.makedirs(ymdir2, exist_ok=True)    
            sfilename = blanksfile('', 'L', 'gt  ', evtime=otime, nordic_format='OLD')
            sfile_path = os.path.join(ymdir2, sfilename) 
            print(f'Found {num_wavfiles} matching WAVs. creating {sfilename} in {ymdir2}')
            shutil.move(sfilename, sfile_path)
            total_unmatched += 1
        print(f'Matched {total_matched}, Unmatched {total_unmatched}')
         
# Associate MiniSEED files with events
wav_catalog = catalog.copy()
associate_miniseed_with_events(wav_catalog, df)

# Save the updated catalog with comments
wav_catalog.write(wavqmlfile, format="QUAKEML")
print(f"\n✅ Updated catalog saved as {wavqmlfile}")
# Out:
# Event: smi:local/38f0539c-f72c-47b6-ae20-450a556f4d12, Associated Files: set()
# Found 0 matching WAVs. creating 02-1305-09L.S197003 in /data/SEISAN_DB/REA/PINATnew2/1970/03
# Matched 0, Unmatched 1
# /home/thompsong/miniconda3new/envs/passoft3/lib/python3.10/site-packages/obspy/io/nordic/core.py:1363: UserWarning: Desired sfile: 02-1305-08L.S197003 exists, will not overwrite
#   warnings.warn('Desired sfile: ' + sfile + ' exists, will not ' +
# Event: smi:local/416d7503-22fc-42a6-863c-7db30b0923fa, Associated Files: set()
# Found 0 matching WAVs. creating 02-1305-09L.S197003 in /data/SEISAN_DB/REA/PINATnew2/1970/03
# Matched 0, Unmatched 2
# Event: smi:local/6fd8a2f8-329d-4987-8fdb-ca8f6185bc1f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-0310-09M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-01T03:10:19.170000Z
# Found 1 matching WAVs. creating 01-0310-09L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1, Unmatched 2
# /home/thompsong/miniconda3new/envs/passoft3/lib/python3.10/site-packages/obspy/io/nordic/core.py:2169: UserWarning: Evaluation mode None is not mappable
#   warnings.warn("Evaluation mode {0} is not mappable".format(
# Event: smi:local/df4fef67-7c57-4b2c-bf60-64b89a82e609, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-0339-42M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-01T03:39:53.670000Z
# Found 1 matching WAVs. creating 01-0339-42L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 2, Unmatched 2
# Event: smi:local/fbddf66a-2bf3-4fbe-901a-320d8d3e721a, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1045-26M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T10:45:39.420000Z
# Found 1 matching WAVs. creating 01-1045-26L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 3, Unmatched 2
# Event: smi:local/d7d1a59c-d5dc-4bb6-9c43-c47577b8ee11, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1049-40M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T10:49:51.510000Z
# Found 1 matching WAVs. creating 01-1049-40L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 4, Unmatched 2
# Event: smi:local/44641197-fc54-469e-a858-160a00fc8959, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1120-14M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T11:20:26.220000Z
# Found 1 matching WAVs. creating 01-1120-14L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 5, Unmatched 2
# Event: smi:local/7a791207-1319-49df-ad72-e140d897633b, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1148-00M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T11:48:10.850000Z
# Found 1 matching WAVs. creating 01-1148-00L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 6, Unmatched 2
# Event: smi:local/abb52c02-0a33-456b-a458-1e299f683e1d, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1156-02M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T11:56:12.190000Z
# Found 1 matching WAVs. creating 01-1156-02L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 7, Unmatched 2
# Event: smi:local/483b6992-74b7-4891-9202-d79b3e68cdfb, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1305-01M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T13:05:15.760000Z
# Found 1 matching WAVs. creating 01-1305-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 8, Unmatched 2
# Event: smi:local/053e07c9-fdd0-4f0e-82ad-b85077263bb8, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1453-12M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T14:53:24.930000Z
# Found 1 matching WAVs. creating 01-1453-12L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 9, Unmatched 2
# Event: smi:local/8858acab-96cb-4d3e-ba16-dead48cedcb9, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1520-53M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T15:21:03.420000Z
# Found 1 matching WAVs. creating 01-1520-53L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 10, Unmatched 2
# Event: smi:local/39e43776-09d5-4c7e-a6c3-655469643c00, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1531-28M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T15:31:40.210000Z
# Found 1 matching WAVs. creating 01-1531-28L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 11, Unmatched 2
# Event: smi:local/d4d43a27-b615-4049-9a94-570343e09e67, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1538-09M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T15:38:19.030000Z
# Found 1 matching WAVs. creating 01-1538-09L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 12, Unmatched 2
# Event: smi:local/55a7b8e9-c9a1-4a50-9247-ae5c699be4c1, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1555-46M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T15:55:58.450000Z
# Found 1 matching WAVs. creating 01-1555-46L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 13, Unmatched 2
# Event: smi:local/29ef9181-4ff3-4f28-bb15-bacccc3623de, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1610-40M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T16:10:50.890000Z
# Found 1 matching WAVs. creating 01-1610-40L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 14, Unmatched 2
# Event: smi:local/50efc8c0-74ce-449e-9769-f7a83cbaf47b, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1620-49M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T16:20:58.960000Z
# Found 1 matching WAVs. creating 01-1620-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 15, Unmatched 2
# Event: smi:local/298831ec-1953-4984-99ed-dc9eb129fad6, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1644-01M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T16:44:13.310000Z
# Found 1 matching WAVs. creating 01-1644-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 16, Unmatched 2
# Event: smi:local/506c3074-ab85-4d00-8052-42a5d48054e1, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1700-26M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T17:00:36.310000Z
# Found 1 matching WAVs. creating 01-1700-26L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 17, Unmatched 2
# Event: smi:local/5c061646-8568-4d94-9f1c-92803b0979ed, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1703-19M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T17:03:29.110000Z
# Found 1 matching WAVs. creating 01-1703-19L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 18, Unmatched 2
# Event: smi:local/3b4ae666-9df4-4451-8d1b-b3304f3adcf6, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1748-36M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T17:48:47.410000Z
# Found 1 matching WAVs. creating 01-1748-36L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 19, Unmatched 2
# Event: smi:local/38ad00b8-59ac-42fd-8378-b1fc53858601, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-1928-55M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T19:29:08.090000Z
# Found 1 matching WAVs. creating 01-1928-55L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 20, Unmatched 2
# Event: smi:local/c32e3480-b243-4d4c-a3f7-707af2704e27, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-2014-53M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T20:15:06.640000Z
# Found 1 matching WAVs. creating 01-2014-53L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 21, Unmatched 2
# Event: smi:local/46ca9e00-2edc-45e8-adda-421ac09c498c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-2035-27M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T20:35:39.360000Z
# Found 1 matching WAVs. creating 01-2035-27L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 22, Unmatched 2
# Event: smi:local/aaf292b2-80bf-4cf5-b67f-0948283bbf5d, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-2115-09M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T21:15:20.600000Z
# Found 1 matching WAVs. creating 01-2115-09L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 23, Unmatched 2
# Event: smi:local/e411e63a-b76f-4e41-9c81-b907b75f6956, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-01-2121-40M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-01T21:21:53.720000Z
# Found 1 matching WAVs. creating 01-2121-40L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 24, Unmatched 2
# Event: smi:local/a0f4170a-cb8e-4eb6-b754-3411b0938afa, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-02-2048-14M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-02T20:48:23.180000Z
# Found 1 matching WAVs. creating 02-2048-14L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 25, Unmatched 2
# Event: smi:local/e3122696-3c6b-4675-95c7-dac935c3e9e9, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-02-2251-07M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-02T22:51:19.890000Z
# Found 1 matching WAVs. creating 02-2251-07L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 26, Unmatched 2
# Event: smi:local/7fa68eb2-55ca-4231-8670-266c9bc59ba2, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-02-2259-45M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-02T22:59:55.020000Z
# Found 1 matching WAVs. creating 02-2259-45L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 27, Unmatched 2
# Event: smi:local/ab463920-d0ff-493f-98e6-71ed01f17672, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0008-49M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:08:59.680000Z
# Found 1 matching WAVs. creating 03-0008-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 28, Unmatched 2
# Event: smi:local/44e8e609-e1e2-4e69-9b33-e5c90963722f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0018-02M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:18:13.210000Z
# Found 1 matching WAVs. creating 03-0018-02L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 29, Unmatched 2
# Event: smi:local/fbb01c88-68c3-4fc3-a177-54e169798f59, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0019-14M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:19:28.110000Z
# Found 1 matching WAVs. creating 03-0019-14L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 30, Unmatched 2
# Event: smi:local/7d344539-337f-4593-8f80-23e376756f0c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0020-25M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:20:34.980000Z
# Found 1 matching WAVs. creating 03-0020-25L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 31, Unmatched 2
# Event: smi:local/84504633-845a-4c48-9725-684f4fd2b3f7, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0020-25M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:20:42.960000Z
# Found 1 matching WAVs. creating 03-0020-25L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 32, Unmatched 2
# Event: smi:local/cb0746b4-5354-4ca9-b5e2-d9cfd0cdcd39, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0023-33M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T00:23:43.080000Z
# Found 1 matching WAVs. creating 03-0023-33L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 33, Unmatched 2
# Event: smi:local/9ba5f3c8-58b1-4aef-8be7-3435ffc3d169, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0107-39M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T01:07:49.620000Z
# Found 1 matching WAVs. creating 03-0107-39L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 34, Unmatched 2
# Event: smi:local/9abefb88-4211-416a-a9af-9fd630121ceb, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-03-0125-15M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-03T01:25:23.750000Z
# Found 1 matching WAVs. creating 03-0125-15L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched
.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T06:38:09.230000Z
# Found 1 matching WAVs. creating 04-0637-56L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 85, Unmatched 2
# Event: smi:local/bd9f734c-5b7c-473d-8750-3e7340fa7b16, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0707-45M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T07:07:58.010000Z
# Found 1 matching WAVs. creating 04-0707-45L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 86, Unmatched 2
# Event: smi:local/54c4951c-555f-460f-999c-0b7ce10e98b7, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0726-12M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T07:26:23.130000Z
# Found 1 matching WAVs. creating 04-0726-12L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 87, Unmatched 2
# Event: smi:local/fec94712-e03e-460c-b4ce-3f3112b1c56c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0731-47M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T07:31:58.810000Z
# Found 1 matching WAVs. creating 04-0731-47L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 88, Unmatched 2
# Event: smi:local/48f207ba-db1e-43bc-a3f1-41d6d1404a98, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0735-56M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T07:36:07.730000Z
# Found 1 matching WAVs. creating 04-0735-56L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 89, Unmatched 2
# Event: smi:local/ea589311-d2d3-4d41-8346-8f0490ade8b0, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0754-18M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T07:54:21.560000Z
# Found 1 matching WAVs. creating 04-0754-18L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 90, Unmatched 2
# Event: smi:local/153328e4-f4ff-4859-ab7b-5dd04d8cb340, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0801-04M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T08:01:15.110000Z
# Found 1 matching WAVs. creating 04-0801-04L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 91, Unmatched 2
# Event: smi:local/5e5d1f2b-7247-417e-9b05-7c2a8e2f976f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0827-54M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T08:28:05.830000Z
# Found 1 matching WAVs. creating 04-0827-54L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 92, Unmatched 2
# Event: smi:local/f565c1f3-b891-418e-916b-c27555ff10ab, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0853-39M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T08:53:52.780000Z
# Found 1 matching WAVs. creating 04-0853-39L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 93, Unmatched 2
# Event: smi:local/afcfbfdb-1dbd-4cbd-aaff-c9b58e902d2c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-0935-39M.PINAT_004'}
# 📌 Added MiniSEED association for Event at 1991-05-04T09:35:49.810000Z
# Found 1 matching WAVs. creating 04-0935-39L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 94, Unmatched 2
# Event: smi:local/70835a9e-2088-4db7-b2da-a832a9ae9e9c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1034-24M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T10:34:38.350000Z
# Found 1 matching WAVs. creating 04-1034-24L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 95, Unmatched 2
# Event: smi:local/e8edde2f-2809-4474-a046-2f6e4fa052b2, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1041-01M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T10:41:12.590000Z
# Found 1 matching WAVs. creating 04-1041-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 96, Unmatched 2
# Event: smi:local/2937a229-1a3a-4428-9288-a6b1253a7a94, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1055-29M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T10:55:42.010000Z
# Found 1 matching WAVs. creating 04-1055-29L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 97, Unmatched 2
# Event: smi:local/aae6d7ca-cd1b-4016-bb68-2aee4fd3b692, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1101-40M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T11:01:52.070000Z
# Found 1 matching WAVs. creating 04-1101-40L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 98, Unmatched 2
# Event: smi:local/0925cdcf-3645-4b8d-9240-b265f6c5a8e9, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1109-37M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T11:09:49.390000Z
# Found 1 matching WAVs. creating 04-1109-37L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 99, Unmatched 2
# Event: smi:local/b7fa8992-2358-417d-aed3-7d90c7024efd, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1145-51M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T11:46:01.900000Z
# Found 1 matching WAVs. creating 04-1145-51L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 100, Unmatched 2
# Event: smi:local/8460f1ce-eef3-463b-9e7e-4c60ae055997, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1403-19M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T14:03:32.220000Z
# Found 1 matching WAVs. creating 04-1403-19L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 101, Unmatched 2
# Event: smi:local/b79ca963-e27a-4d62-ae15-2348f22c2fbb, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1509-01M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T15:09:12.690000Z
# Found 1 matching WAVs. creating 04-1509-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 102, Unmatched 2
# Event: smi:local/c2054e36-5c00-4969-bc54-58c753509393, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1545-04M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T15:45:13.030000Z
# Found 1 matching WAVs. creating 04-1545-04L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 103, Unmatched 2
# Event: smi:local/5614174d-3596-4672-b142-77bac8151857, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1615-43M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T16:15:55.370000Z
# Found 1 matching WAVs. creating 04-1615-43L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 104, Unmatched 2
# Event: smi:local/e14799b7-2c2a-409a-9b59-d9c01c20b94f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1635-16M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T16:35:25.450000Z
# Found 1 matching WAVs. creating 04-1635-16L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 105, Unmatched 2
# Event: smi:local/c52d2c65-0f7a-4c39-983c-73e2322706f5, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1636-17M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T16:36:29.900000Z
# Found 1 matching WAVs. creating 04-1636-17L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 106, Unmatched 2
# Event: smi:local/86ff2bce-6051-4bdd-8cc9-71c9376aa736, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1650-25M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T16:50:35.640000Z
# Found 1 matching WAVs. creating 04-1650-25L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 107, Unmatched 2
# Event: smi:local/5d60502a-6614-414b-aabe-fbc8ff922094, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1705-14M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T17:05:25.560000Z
# Found 1 matching WAVs. creating 04-1705-14L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 108, Unmatched 2
# Event: smi:local/067c6697-7a34-42c3-ac2a-5baa70d32ec8, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1758-49M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T17:58:58.490000Z
# Found 1 matching WAVs. creating 04-1758-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 109, Unmatched 2
# Event: smi:local/3db85b2d-861f-4595-bd5a-178e045a93ca, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1815-50M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T18:16:00.190000Z
# Found 1 matching WAVs. creating 04-1815-50L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 110, Unmatched 2
# Event: smi:local/5c9807e8-d170-47a6-b63f-90a67fa15635, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1817-11M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T18:17:22.780000Z
# Found 1 matching WAVs. creating 04-1817-11L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 111, Unmatched 2
# Event: smi:local/976c9d8e-76c5-4cca-9106-2b97d1a59a99, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1842-40M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T18:42:52.930000Z
# Found 1 matching WAVs. creating 04-1842-40L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 112, Unmatched 2
# Event: smi:local/c2b0567a-4d1b-4fb1-bb1d-25bf39595762, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1851-49M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T18:51:57.580000Z
# Found 1 matching WAVs. creating 04-1851-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 113, Unmatched 2
# Event: smi:local/d9d6dd60-b227-4214-aaa2-dff957c3ada9, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1915-51M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T19:16:06.060000Z
# Found 1 matching WAVs. creating 04-1915-51L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 114, Unmatched 2
# Event: smi:local/53a65997-3e7f-4a0c-b8a7-086cd9c64b05, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1919-29M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T19:19:40.010000Z
# Found 1 matching WAVs. creating 04-1919-29L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 115, Unmatched 2
# Event: smi:local/7946eff6-029c-4955-92cb-c4aa0b13835f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1919-29M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T19:19:56.390000Z
# Found 1 matching WAVs. creating 04-1919-29L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 116, Unmatched 2
# Event: smi:local/53fafa37-9692-4dfe-a77b-f1682e77b71f, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-1942-06M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04T19:42:16.740000Z
# Found 1 matching WAVs. creating 04-1942-06L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 117, Unmatched 2
# Event: smi:local/88995291-45f7-40c6-b1af-c74f1da9fc36, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-04-2059-43M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-04
.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T03:19:57.300000Z
# Found 1 matching WAVs. creating 05-0319-46L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 134, Unmatched 2
# Event: smi:local/cffcb405-ea1b-4167-8bcc-8b3a6022f712, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0321-07M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T03:21:20.680000Z
# Found 1 matching WAVs. creating 05-0321-07L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 135, Unmatched 2
# Event: smi:local/7193f1d3-33b8-4194-91df-33444bf5422d, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0417-10M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T04:17:19.800000Z
# Found 1 matching WAVs. creating 05-0417-10L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 136, Unmatched 2
# Event: smi:local/026c2112-a5c6-4b3b-8c83-93e62552bcdd, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0512-47M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T05:12:59.710000Z
# Found 1 matching WAVs. creating 05-0512-47L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 137, Unmatched 2
# Event: smi:local/4ad6b205-a52d-4415-a900-759e2c693482, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0514-13M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T05:14:26.040000Z
# Found 1 matching WAVs. creating 05-0514-13L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 138, Unmatched 2
# Event: smi:local/6497ac76-a513-460c-91e7-79f8eb441448, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0517-26M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T05:17:36.660000Z
# Found 1 matching WAVs. creating 05-0517-26L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 139, Unmatched 2
# Event: smi:local/3159261d-dd7f-4bc8-94f3-5434a7ae2f07, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0520-44M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T05:20:54.590000Z
# Found 1 matching WAVs. creating 05-0520-44L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 140, Unmatched 2
# Event: smi:local/e1bc7a03-208b-4183-a987-f0d445a6e4ec, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0528-41M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T05:28:48.690000Z
# Found 1 matching WAVs. creating 05-0528-41L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 141, Unmatched 2
# Event: smi:local/af59faae-d654-42a1-84c1-ddefcd3f00bc, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0646-14M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T06:46:26.290000Z
# Found 1 matching WAVs. creating 05-0646-14L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 142, Unmatched 2
# Event: smi:local/da277ce6-0f35-4ac6-ab42-281ab976b28c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0923-11M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T09:23:22.680000Z
# Found 1 matching WAVs. creating 05-0923-11L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 143, Unmatched 2
# Event: smi:local/f2d0dfb2-cb39-43b9-b613-b7b07c290517, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-0954-20M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T09:54:31.890000Z
# Found 1 matching WAVs. creating 05-0954-20L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 144, Unmatched 2
# Event: smi:local/4b5d49e8-ccf5-4476-b78b-ae25e308e558, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-05-1257-00M.PINAT_005'}
# 📌 Added MiniSEED association for Event at 1991-05-05T12:57:11.000000Z
# Found 1 matching WAVs. creating 05-1257-00L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# ...
# 📌 Added MiniSEED association for Event at 1991-05-30T03:10:43.430000Z
# Found 1 matching WAVs. creating 30-0310-29L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1372, Unmatched 2
# Event: smi:local/10bef7f6-ee2a-4dbd-9ca2-dd75f7805cab, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0316-20M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T03:16:31.940000Z
# Found 1 matching WAVs. creating 30-0316-20L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1373, Unmatched 2
# Event: smi:local/a3d3f2b4-479e-47e7-a168-0224972a2890, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0319-28M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T03:19:41.400000Z
# Found 1 matching WAVs. creating 30-0319-28L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1374, Unmatched 2
# Event: smi:local/d43d9779-112f-4d4b-9d28-d2d42db703cb, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0320-19M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T03:20:32.370000Z
# Found 1 matching WAVs. creating 30-0320-19L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1375, Unmatched 2
# Event: smi:local/291058d9-82fc-4bee-9593-08a801aa1af7, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0343-45M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T03:43:53.410000Z
# Found 1 matching WAVs. creating 30-0343-45L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1376, Unmatched 2
# Event: smi:local/52b0ea88-235e-4173-8ef9-c7e50b743f83, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0429-13M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T04:29:25.780000Z
# Found 1 matching WAVs. creating 30-0429-13L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1377, Unmatched 2
# Event: smi:local/2d5c93b4-f3f8-4b8e-97f3-3bf12e9bf657, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0459-16M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T04:59:25.770000Z
# Found 1 matching WAVs. creating 30-0459-16L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1378, Unmatched 2
# Event: smi:local/30eb2e32-bea9-44e8-80e8-53db0a2692de, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0509-00M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T05:09:09.280000Z
# Found 1 matching WAVs. creating 30-0509-00L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1379, Unmatched 2
# Event: smi:local/89c74b74-68e0-4756-8acf-74a5c9a7d72e, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0550-59M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T05:51:14.340000Z
# Found 1 matching WAVs. creating 30-0550-59L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1380, Unmatched 2
# Event: smi:local/3ea4a89e-502b-4568-bb18-225d810f4ab2, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0553-06M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T05:53:16.850000Z
# Found 1 matching WAVs. creating 30-0553-06L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1381, Unmatched 2
# Event: smi:local/c037133d-4704-4b24-a839-deb4da22b057, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0604-42M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T06:04:57.100000Z
# Found 1 matching WAVs. creating 30-0604-42L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1382, Unmatched 2
# Event: smi:local/980c5a9a-9256-422f-84ec-74e779908888, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0620-32M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T06:20:46.260000Z
# Found 1 matching WAVs. creating 30-0620-32L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1383, Unmatched 2
# Event: smi:local/7f207663-f2b7-4d92-9620-50aa8fac90b8, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0639-09M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T06:39:23.310000Z
# Found 1 matching WAVs. creating 30-0639-09L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1384, Unmatched 2
# Event: smi:local/ed947a0a-a430-4171-bc0d-b8ea38629839, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0645-15M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T06:45:25.180000Z
# Found 1 matching WAVs. creating 30-0645-15L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1385, Unmatched 2
# Event: smi:local/594536fd-9a3c-4b03-b894-31f6172954da, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0823-57M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T08:24:11.560000Z
# Found 1 matching WAVs. creating 30-0823-57L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1386, Unmatched 2
# Event: smi:local/58551f64-9a12-4cd7-b11a-5fb7705b01c4, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0856-53M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T08:57:03.520000Z
# Found 1 matching WAVs. creating 30-0856-53L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1387, Unmatched 2
# Event: smi:local/b52f6525-72e5-4a98-9127-f13c2fce33f0, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0915-50M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T09:16:03.370000Z
# Found 1 matching WAVs. creating 30-0915-50L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1388, Unmatched 2
# Event: smi:local/b8025df1-5fe7-488c-9acc-5ec3e2b1dc80, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-0938-01M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T09:38:15.630000Z
# Found 1 matching WAVs. creating 30-0938-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1389, Unmatched 2
# Event: smi:local/9e540971-b09c-4afd-b380-bcb7c228ac4b, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1004-46M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T10:04:59.410000Z
# Found 1 matching WAVs. creating 30-1004-46L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1390, Unmatched 2
# Event: smi:local/4eb5aee5-84f5-4097-920a-4aeb4cedb6a9, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1004-46M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T10:04:59.410000Z
# Found 1 matching WAVs. creating 30-1004-46L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1391, Unmatched 2
# Event: smi:local/34443229-3ba5-4c3e-88bc-f6567841ac4b, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1055-13M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T10:55:24.640000Z
# Found 1 matching WAVs. creating 30-1055-13L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1392, Unmatched 2
# Event: smi:local/b9a1ceef-3fe7-427f-8b53-c3e4809e5a3e, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1105-07M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T11:05:20.420000Z
# Found 1 matching WAVs. creating 30-1105-07L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1393, Unmatched 2
# Event: smi:local/4ffecc6c-6a67-41cf-96e3-220ebf92ebc6, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1119-21M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T11:19:34.050000Z
# Found 1 matching WAVs. creating 30-1119-21L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1394, Unmatched 2
# Event: smi:local/db5d0bb8-018d-442e-a795-51c873ce7270, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1119-21M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T11:19:34.050000Z
# Found 1 matching WAVs. creating 30-1119-21L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1395, Unmatched 2
# Event: smi:local/2b712f8a-061d-4ba8-bf7a-00969e9f6499, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1206-09M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T12:06:21.920000Z
# Found 1 matching WAVs. creating 30-1206-09L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1396, Unmatched 2
# Event: smi:local/deda5e1e-f245-42cd-a1af-bbebd9612dbb, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1235-01M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T12:35:10.310000Z
# Found 1 matching WAVs. creating 30-1235-01L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1397, Unmatched 2
# Event: smi:local/f81c03ec-763a-43ea-bd91-3d76d75de3f7, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1310-33M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T13:10:46.360000Z
# Found 1 matching WAVs. creating 30-1310-33L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1398, Unmatched 2
# Event: smi:local/cf0b8910-7bf9-46d0-b650-96dd18cc32e7, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1310-33M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T13:10:46.360000Z
# Found 1 matching WAVs. creating 30-1310-33L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1399, Unmatched 2
# Event: smi:local/9539eb3f-d11d-471b-ab1e-7b0d6d5e7e63, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1350-25M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T13:50:37.370000Z
# Found 1 matching WAVs. creating 30-1350-25L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1400, Unmatched 2
# Event: smi:local/7afa05ad-4481-4615-a9b5-e0dd71710dbf, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1350-25M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T13:50:37.370000Z
# Found 1 matching WAVs. creating 30-1350-25L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1401, Unmatched 2
# Event: smi:local/7817e351-9d40-4ef0-81c0-4eea7b6a40b5, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1403-27M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:03:38.070000Z
# Found 1 matching WAVs. creating 30-1403-27L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1402, Unmatched 2
# Event: smi:local/f8be782a-ddd8-4db6-b02b-7c35e84e0045, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1403-27M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:03:38.070000Z
# Found 1 matching WAVs. creating 30-1403-27L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1403, Unmatched 2
# Event: smi:local/4a8a3742-0208-4f8a-bb2d-f7c51a656c9c, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1420-28M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:20:41.450000Z
# Found 1 matching WAVs. creating 30-1420-28L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1404, Unmatched 2
# Event: smi:local/f7d785f5-e982-4306-b60d-c0674ca18057, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1420-28M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:20:41.450000Z
# Found 1 matching WAVs. creating 30-1420-28L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1405, Unmatched 2
# Event: smi:local/1be0f69d-40c2-4caf-a637-4590ace967d3, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1437-49M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:38:00.950000Z
# Found 1 matching WAVs. creating 30-1437-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1406, Unmatched 2
# Event: smi:local/207ca647-d032-4c16-92b4-187c8c234318, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1437-49M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:38:37.540000Z
# Found 1 matching WAVs. creating 30-1437-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1407, Unmatched 2
# Event: smi:local/414801f0-e8de-47aa-87f0-ec39c5ed2c63, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1437-49M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:38:37.540000Z
# Found 1 matching WAVs. creating 30-1437-49L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1408, Unmatched 2
# Event: smi:local/cd8b04f1-447c-4ede-b287-7b399a9a747d, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1446-32M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:46:46.540000Z
# Found 1 matching WAVs. creating 30-1446-32L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1409, Unmatched 2
# Event: smi:local/5f60af25-4e1c-4613-88be-429e1d0d1d23, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1446-32M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:46:46.540000Z
# Found 1 matching WAVs. creating 30-1446-32L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1410, Unmatched 2
# Event: smi:local/12221c3c-bd34-422b-a332-52339e3249c8, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1448-04M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T14:49:04.480000Z
# Found 1 matching WAVs. creating 30-1448-04L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1411, Unmatched 2
# Event: smi:local/efc296c5-e7f4-4df0-95c0-b225398fd9a3, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1526-30M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T15:27:12.420000Z
# Found 1 matching WAVs. creating 30-1526-30L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1412, Unmatched 2
# Event: smi:local/56935c24-17c1-48a3-a3fe-c4c4b029b889, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1545-02M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T15:45:19.690000Z
# Found 1 matching WAVs. creating 30-1545-02L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# Matched 1413, Unmatched 2
# Event: smi:local/b4d3f2b1-cd4e-4b5f-b188-6e045f0211c6, Associated Files: {'/data/SEISAN_DB/WAV/PINAT/1991/05/1991-05-30-1548-10M.PINAT_009'}
# 📌 Added MiniSEED association for Event at 1991-05-30T15:48:25.900000Z
# Found 1 matching WAVs. creating 30-1548-10L.S199105 in /data/SEISAN_DB/REA/PINAT2/1991/05
# ---------------------------------------------------------------------------
# NordicParsingError                        Traceback (most recent call last)
# Cell In[28], line 74
#      72 # Associate MiniSEED files with events
#      73 wav_catalog = catalog.copy()
# ---> 74 associate_miniseed_with_events(wav_catalog, df)
#      76 # Save the updated catalog with comments
#      77 wav_catalog.write(wavqmlfile, format="QUAKEML")
#
# Cell In[28], line 58, in associate_miniseed_with_events(catalog, df)
#      56     filename = stime.strftime("%d-%H%M-%S") + "L.S" + stime.strftime("%Y%m")
#      57     print(f'Found {num_wavfiles} matching WAVs. creating {filename} in {ymdir}')
# ---> 58     _write_nordic(event, filename, userid='gt  ', evtype='L', outdir=ymdir, wavefiles=os.path.basename(wavfile),
#      59               explosion=False, nordic_format='OLD', overwrite=True, high_accuracy=False)
#      60     total_matched += 1
#      61 else:
#      62     # write a new sfile with the picks
#
# File ~/miniconda3new/envs/passoft3/lib/python3.10/site-packages/obspy/io/nordic/core.py:1630, in _write_nordic(event, filename, userid, evtype, outdir, wavefiles, explosion, nordic_format, overwrite, string_io, high_accuracy)
#    1628 # Now call the populate sfile function
#    1629 if len(event.picks) > 0:
# -> 1630     newpicks = '\n'.join(nordpick(event, high_accuracy=high_accuracy,
#    1631                                   nordic_format=nordic_format))
#    1632     sfile.write(newpicks + '\n')
#    1633     sfile.write('\n'.rjust(81))
#
# File ~/miniconda3new/envs/passoft3/lib/python3.10/site-packages/obspy/io/nordic/core.py:2189, in nordpick(event, high_accuracy, nordic_format)
#    2187     days_diff = (pick.time.date - origin_date).days
#    2188     if days_diff > 1:
# -> 2189         raise NordicParsingError(
#    2190             "Pick is {0} days from the origin, must be < 48 "
#    2191             "hours".format(days_diff))
#    2192     pick_hour += 24
#    2193 pick_seconds = pick.time.second + (pick.time.microsecond / 1e6)
#
# NordicParsingError: Pick is 6940 days from the origin, must be < 48 hours
